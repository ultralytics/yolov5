# %%
# !git clone https://github.com/pourmand1376/yolov5/
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17744, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 17744 (delta 33), reused 38 (delta 18), pack-reused 17686
# Receiving objects: 100% (17744/17744), 14.59 MiB | 34.59 MiB/s, done.
# Resolving deltas: 100% (12225/12225), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !git checkout add_gradcam
# Out:
# Branch 'add_gradcam' set up to track remote branch 'add_gradcam' from 'origin'.
# Switched to a new branch 'add_gradcam'

# %%
# !git pull
# Out:
# Already up to date.

# %%
# !pip install -qqr requirements.txt
# Out:
#      |████████████████████████████████| 182 kB 24.9 MB/s
#      |████████████████████████████████| 62 kB 1.3 MB/s
#      |████████████████████████████████| 1.6 MB 59.4 MB/s

# %%
pip install grad-cam -qq
# Out:
#      |████████████████████████████████| 7.8 MB 18.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...

# %%
# !python explainer.py --source data/images/zidane.jpg --verbose
# Out:
# explainer: weights=yolov5s.pt, source=data/images/zidane.jpg, imgsz=[640, 640], iou_thres=0.45, device=, verbose=True
# /usr/local/lib/python3.8/dist-packages/torch/hub.py:267: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 v6.1-729-gf6da327e Python-3.8.16 torch-1.13.0+cu116 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 226MB/s]
#
# ...

# %%
from explainer import run
output=run(source='data/images/zidane.jpg')
from PIL import Image
output
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 v6.1-729-gf6da327e Python-3.8.16 torch-1.13.0+cu116 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 384x640 2 persons, 1 tie
# Speed: 4.1ms pre-process, 284.1ms inference, 1.1ms NMS per image at shape (1, 3, 384, 640)
# Saved 1 image to runs/detect/exp5
# CAM image is now ready
# <PIL.Image.Image image mode=RGB size=640x384 at 0x7F40A36EC6D0>
