# %%
import cv2
from matplotlib import pyplot as plt
from yolov5 import Yolov5

# %%
yolov5 = Yolov5('weights/yolov5x.pt')
# Out:
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11264MB)
#            device1 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11264MB)
#
# Fusing layers... Model Summary: 284 layers, 8.89222e+07 parameters, 8.45317e+07 gradients

# %%
print(yolov5)
# Out:
# Model: yolov5x.pt
# Image size: 640
# Confidence threshold: 0.4
# IoU threshold: 0.5
# Augment: False
# Agnostic nms: False
# Classes: ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush']

# %%
zidane_image = cv2.imread('inference/images/zidane.jpg')

# %%
yolov5.predict(zidane_image)
# Out:
# [{'bndbox': {'xmin': 748, 'xmax': 1144, 'ymin': 43, 'ymax': 710},
#   'name': 'person',
#   'conf': 0.9317386150360107,
#   'color': [218, 167, 246]},
#  {'bndbox': {'xmin': 434, 'xmax': 526, 'ymin': 436, 'ymax': 717},
#   'name': 'tie',
#   'conf': 0.862044095993042,
#   'color': [223, 152, 168]},
#  {'bndbox': {'xmin': 120, 'xmax': 1056, 'ymin': 201, 'ymax': 711},
#   'name': 'person',
#   'conf': 0.8162736892700195,
#   'color': [218, 167, 246]},
#  {'bndbox': {'xmin': 985, 'xmax': 1135, 'ymin': 308, 'ymax': 704},
#   'name': 'tie',
#   'conf': 0.5196189880371094,
#   'color': [223, 152, 168]}]

# %%
plt.imshow(cv2.cvtColor(zidane_image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
result = yolov5.predict(zidane_image, draw_bndbox=True)

# %%
plt.imshow(cv2.cvtColor(zidane_image, cv2.COLOR_BGR2RGB))
plt.show()
